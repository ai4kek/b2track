# %% [markdown]
# ## _`basf2` testing_

# %%
import sys
import basf2 as b2
import modularAnalysis as ma
from variables import variables as vm
import variables.collections as vc
import variables.utils as vu

# %%
import uproot
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
print(b2.getStoreObjects())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 print(b2.getStoreObjects())
#
# AttributeError: module 'basf2' has no attribute 'getStoreObjects'
